# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data={
    'Hours': [1,2,3,4,5,6,7,8],
    'Marks':[25,35,45,50,55,65,70,80]
}
df=pd.DataFrame(data)
df
# Out:
#    Hours  Marks
# 0      1     25
# 1      2     35
# 2      3     45
# 3      4     50
# 4      5     55
# 5      6     65
# 6      7     70
# 7      8     80

# %%
#Define Features and Target
x=df[['Hours']]
y=df['Marks']

# %%
# Split data into train & test sets
X_train, X_test,y_train,y_test= train_test_split(x,y,test_size=0.5, random_state=0)
print('Training sample:', len(X_train))
print('Training samples:', len(X_test))
# Out:
# Training sample: 4
# Training samples: 4

# %%
# Create the model and train the model
model= LinearRegression()
model.fit(X_train,y_train)
print('Model trained successfully!')
# Out:
# Model trained successfully!

# %%
y_pred= model.predict(X_test)
print(y_test.values)
print(X_test)
print('Actual:', list(y_test.values))
print('Predicted:', list(y_pred))
# Out:
# [70 45 35 80]
#    Hours
# 6      7
# 2      3
# 1      2
# 7      8
# Actual: [np.int64(70), np.int64(45), np.int64(35), np.int64(80)]
# Predicted: [np.float64(72.32142857142858), np.float64(40.89285714285714), np.float64(33.03571428571428), np.float64(80.17857142857144)]
